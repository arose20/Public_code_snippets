# %% [markdown]
# # Test store magic using a different kernel

# %%
# Use %store to retrieve the variable from the previous session
# %store -r my_variable_2

# Now you can use the variable in this session
print(my_variable_2)
# Out:
# Hello, passing to another session 2!

# %%
# Use %store to retrieve the variable from the previous session
# %store -r my_variable_1

my_variable_1 += ' New value'

# Now you can use the variable in this session
print(my_variable_1)
# Out:
# Hello, passing to another session! New value

# %%
# Use %store to retrieve the variable from the previous session
# %store -r my_variable_1

#my_variable_1 += ' New value'

# Now you can use the variable in this session
print(my_variable_1)
# Out:
# Hello, passing to another session!

# %% [markdown]
# # Can be passed in even if different kernel
