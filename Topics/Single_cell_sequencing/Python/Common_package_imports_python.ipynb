# %% [markdown]
# ### Generic ish

# %%
import os, sys, subprocess, re, glob
from pathlib import Path
from collections import Counter
from collections import defaultdict
import numpy as np
import pandas as pd
import scanpy
#import scvi
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(color_codes=True)
import tqdm.notebook as tqdm
import scipy
import sklearn
import itertools
import math
import pickle as pkl
import logging
import datetime
import time
import gc
import warnings

# Create useful starting variables

#to set unique date for outputs
calc_date = datetime.datetime.now()
date=calc_date.strftime('%Y-%m-%d')
#date=calc_date.strftime('%d-%m-%Y')
date = date.replace('-', '')

cwd = os.getcwd()


print('All packages imported and common variables defined:')
print("Current working directory loaded as 'cwd': " {cwd})
print("Date loaded as 'date': " {cwd})

# %% [markdown]
# ### Classification model

# %%
import os, sys, subprocess, re, glob
from pathlib import Path
from collections import Counter
from collections import defaultdict
import numpy as np
from numpy import cov
import pandas as pd
import scanpy
#import scvi
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(color_codes=True)
import tqdm.notebook as tqdm
import scipy
import scipy.sparse as sparse
import sklearn
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score
from sklearn.metrics import fbeta_score, make_scorer
from sklearn.metrics import log_loss
from sklearn.datasets import make_classification
from sklearn.gaussian_process.kernels import RBF
from skopt import BayesSearchCV
from skopt.callbacks import DeadlineStopper, VerboseCallback
import pymc3 as pm
import itertools
import math
import pickle as pkl
import logging
import datetime
import time
import gc
import warnings

# Create useful starting variables

#to set unique date for outputs
calc_date = datetime.datetime.now()
date=calc_date.strftime('%Y-%m-%d')
#date=calc_date.strftime('%d-%m-%Y')
date = date.replace('-', '')

cwd = os.getcwd()


print('All packages imported and common variables defined:')
print("Current working directory loaded as 'cwd': " {cwd})
print("Date loaded as 'date': " {cwd})

# %% [markdown]
# ### Spatial

# %% [markdown]
# ### Batch correction / integration
