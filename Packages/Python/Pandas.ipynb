# %% [markdown]
# # Pandas

# %% [markdown]
# ## Series

# %%
srs = pd.Series([1,2,3,4]), index=['a', 'b', 'c', 'd'])

# %%
# series name
srs.name = "Insert name"

# series index name
srs.index.name

# get the first element
srs[0]

# get the last element
srs[-1]

# get first n series
srs[:n]

# get last n series
srs[-n:]

# sort series by labels along an axis
srs.sort_index(self, axis=0, level=None, ascending=True, inplace=False, kind='quicksort', na_position='last', sort_remaining=True)

# add n to all values
srs.add(n)

# subtract n to all values
srs.sub(n)

# multiply n to all values
srs.mul(n)

# divide n to all values
srs.div(n)

# %% [markdown]
# ## Dataframes

# %%
import pandas as pd
# Create a two-dimensional data structure 

df = pd.DataFrame(
         {"a" : [1 ,2, 3],
          "b" : [7, 8, 9],
          "c" : [10, 11, 12]},
        index = [1, 2, 3])

# Specify how you want to organize your DataFrame by columns
df = pd.DataFrame( 
     [[1, 2, 3], 
     [4, 6, 8],
     [10, 11, 12]],
     index=[1, 2, 3], 
     columns=['a', 'b', 'c'])

# print a dataframe
df
print(df)
display(df)

# read a dataframe from a csv
df = pd.read_csv('file.csv')
df = pd.read_csv("data.csv", index_col=0) # set index column

# write a dataframe to a csv
df.to_csv('file.csv')

# read a dataframe from a excel file
df = pd.read_excel('file.xlsx')

# write a dataframe to a excel file
df.to_excel('dir/myDataFrame.xlsx',  sheet_name='Sheet2')

# get the top n rows of a dataframe
df.head(n)

# get the top n elements of a series in a dataframe
df['Name'].head(10)

# get the bottom n rows of a dataframe
df.tail(n)

# get the bottom n elements of a series in a dataframe
df['Name'].tail(10)

# select a single value by position in a dataframe
df.iloc[[0],[0]]
df.iat([0],[0])

# select a single value by label in a dataframe
df.loc[[0], ['Label']]
df.at([0], ['Label'])

# Access a dataframe with a boolean index
dict = {'name':["name1", "name2", "name3", "name4"], 
        'degree': ["degree1", "degree2", "degree3", "degree4"], 
        'score':[1, 2, 3, 4]}
df = pd.DataFrame(dict, index = [True, False, True, False])

# drop values from rows
s.drop(['a', 'c'])

# drop values from columns
df.drop('Value', axis=1)

# create a new column in a dataframe
df['New Column'] = 0

# rename columns in a dataframe
df.columns = ['Column 1', 'Column 2', 'Column 3']

# sort values along an axis ascending order
df.sort_values(by='Values')

# sort values along an axis descending order
df.sort_values(ascending = False)

# add ranks to particular entries
df.rank()

# retrieve rows and columns description
df.shape

# describe columns of a dataframe
df.columns

# retrieve index description
df.index

# get information on a dataframe
df.info()

# retrieve the number of non-NA values
df.count()

# get the sum of values
df.sum()

# get the cumulative sum
df.cumsum()

# get the minimum value of a dataframe
df.min()

# get the maximum value of a dataframe
df.max()

# get the minimum index values
df.idxmin()

# get the maximum index values
df.idxmax()

# get the mean of values
df.mean()

# get the median of values
df.median()

# describe the summary statistics of the data
df.describe()

# apply a function to a dataset
f = def(function)
df.apply(f)

# apply a function by an element
df.applymap(f)

# merge two dataframes
pd.merge(df1, df2, on='column')

# concatenate two dataframes
pd.concat([df1, df2])

# remove unused categories - e.g. slice out unique values, update the column metadata
obs_subset['LVL1'] = obs_subset['LVL1'].cat.remove_unused_categories()
