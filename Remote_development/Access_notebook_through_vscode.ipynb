# %% [markdown]
# # From jupyterlab to vscode
#
# - Generate a token from jupyterlab on the server
# - Open a notebook in vscode
# - select a kernel and click existing or connect to a jupyter kernel (assuming jupyter extension is already installed)
# - enter the server with the token i.e. https://jhub.server/user/{user}/?token={token}
# - enter for username and now select kernels available on the jupyter server
